# %% [markdown]
# # Functions
#
# - basics
# - function arguments and parameters
# - return statement
# - default arguments

# %% [markdown]
# # basics

# %% [markdown]
# # function arguments and parameters
# - return statement
# - default arguments
